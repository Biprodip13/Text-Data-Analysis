# %% [markdown]
# # Test Data Analysis Project
#
# Problem Statement 1: Performing Sentiment analysis on Youtube Comments
#
# Problem Statement 2: Performing EDA analysis for positive Comments
#
# Problem Statement 3: Performing EDA analysis for negative Comments

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
videos=pd.read_csv('F:\Plots\Project 2 dataset/Indiacomments.csv',error_bad_lines=False)
videos.head()
# Out:
# b'Skipping line 41589: expected 4 fields, saw 11\nSkipping line 51628: expected 4 fields, saw 7\nSkipping line 114465: expected 4 fields, saw 5\n'
# b'Skipping line 142496: expected 4 fields, saw 8\nSkipping line 189732: expected 4 fields, saw 6\nSkipping line 245218: expected 4 fields, saw 7\n'
# b'Skipping line 388430: expected 4 fields, saw 5\n'
# c:\python 3.8\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# ...

# %% [markdown]
# # Problem Statement 1: Performing Sentiment analysis on Youtube Comments

# %%
from textblob import TextBlob

# %%
TextBlob('I have been following you from the start of your...').sentiment.polarity
# 1=Poitive polarity
# 0=Neutral Polarity
#-1=Negative Polarity
# Out:
# 0.0

# %%
polarity_store=[]
for i in videos['comment_text']:
    try:
        polarity_store.append(TextBlob(i).sentiment.polarity)
    except:
        polarity_store.append(0)

# %%
videos['polarity_store']=polarity_store

# %%
videos.head(10)
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
# 5  XpVt6Z1Gjjo                            #1 on trending AYYEEEEE     3
# 6  XpVt6Z1Gjjo                               The end though 😭👍🏻❤️     4
# 7  XpVt6Z1Gjjo                               #1 trending!!!!!!!!!     3
# 8  XpVt6Z1Gjjo                        Happy one year vlogaversary     3
# 9  XpVt6Z1Gjjo  You and your shit brother may have single hand...     0
#
#   replies  polarity_store
# 0       0        0.000000
# 1       0        0.000000
# 2       0        0.000000
# 3       0        0.000000
# 4       0        0.000000
# ...

# %% [markdown]
# # Problem Statement 2: Performing EDA analysis for positive Comments

# %%
comments_positive=videos[videos['polarity_store']==1]
comments_positive.head(10)
# Out:
#         video_id                                       comment_text likes  \
# 64   XpVt6Z1Gjjo                                    yu are the best     1
# 156  cLdxuaxaQwc  Power is the disease.  Care is the cure.  Keep...     0
# 227  WYYvHb03Eog  YAS Can't wait to get it! I just need to sell ...     0
# 307  sjlHnJvXdQs                                  This is priceless     0
# 319  sjlHnJvXdQs                                Summed up perfectly     0
# 325  sjlHnJvXdQs                   This is awesome. 1:20 XDDDDDDDDD     0
# 416  cMKX2tE5Luk                                 BEST MOVIE EVER!!!     0
# 433  cMKX2tE5Luk  Power is the disease.  Care is the cure.  Keep...     0
# 447  cMKX2tE5Luk       The greatest movie about the greatest movie.     0
# 469  cMKX2tE5Luk         It's Harry guys he's Spiderman best friend     0
#
#     replies  polarity_store
# 64        0             1.0
# 156       0             1.0
# 227       0             1.0
# 307       0             1.0
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
total_comment=(''.join(comments_positive['comment_text']))
len(total_comment)
wordcloud = WordCloud(width=1000, height=500, stopwords=set(STOPWORDS)).generate(total_comment)
plt.figure(figsize=(15,5))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %% [markdown]
# # Problem Statement 3: Performing EDA analysis for Negative Comments

# %%
comments_negative=videos[videos['polarity_store']==-1]
comments_negative.head(10)
# Out:
#          video_id                                       comment_text likes  \
# 512   8wNr-NQImFg  BEN CARSON IS THE MAN!!!!! THEY HATE HIM CAUSE...     0
# 562   8wNr-NQImFg  Well… The brain surgeon Ben Carson just proved...     0
# 952   Ayb_2qbZHm4         WHY DID YOU MAKE FURRY FORCE?! SO NASTY!!!     0
# 1371  vu_9muoxT50                                     WTF BRUH!!!!!!     0
# 1391  vu_9muoxT50                    cheeseus christ thats insane!!!     0
# 1932  -Ifnaxi2LQg          this is the worst thing i've heard. ever.     0
# 2043  B7YaMkCl3XA  Economy is horrible in Cuba. It's going to be ...     0
# 2088  B7YaMkCl3XA                      Sub to me if this is terrible     0
# 2192  5ywKal6-anc                                           PATHETIC     1
# 2410  EVp4-qjWVJE  I don't like this sportscaster  sounds very an...     0
#
#      replies  polarity_store
# 512        0            -1.0
# 562        0            -1.0
# 952        0            -1.0
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
total_comment=(''.join(comments_negative['comment_text']))
len(total_comment)
wordcloud = WordCloud(width=1000, height=500, stopwords=set(STOPWORDS)).generate(total_comment)
plt.figure(figsize=(15,5))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 999.5, 499.5, -0.5)
